# %%
# First I will Create Decision Tree Model
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
titanic = sns.load_dataset("titanic")

features = ["pclass", "sex", "fare", "embarked", "age"]
target = ["survived"]

# Handle Missing values
imp_median = SimpleImputer(strategy="median")
titanic[["age"]] = imp_median.fit_transform(titanic[["age"]])

imp_freq = SimpleImputer(strategy="most_frequent")
titanic[["embarked"]] = imp_freq.fit_transform(titanic[["embarked"]])

# encode
le = LabelEncoder()

titanic["sex"] = le.fit_transform(titanic["sex"])
titanic["embarked"] = le.fit_transform(titanic["embarked"])

X = titanic[features]
y = titanic["survived"]

# Train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Decsion Tree
model = DecisionTreeClassifier(max_depth=4)

model.fit(X_train, y_train)

y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

print("Training accuracy: ", accuracy_score(y_train, y_pred_train) * 100, "%")
print("Testing accuracy: ", accuracy_score(y_test, y_pred_test) * 100, "%")

# Classic Case of Overfitting
# Out:
# Training accuracy:  84.75120385232745 %
# Testing accuracy:  82.46268656716418 %

# %%
# To plot tree
from sklearn.tree import plot_tree

plt.figure(figsize=(18, 10))
plot_tree(
    model,
    feature_names=X.columns,
    class_names=["Died", "Survived"],
    filled=True
)

plt.tight_layout()

# %% [markdown]
# # Randome Forest Classifier
# ## to actually fix this, for better performance

# %%
from sklearn.ensemble import RandomForestClassifier
# we keep odd number of Decision Model
rf = RandomForestClassifier(
    n_estimators=201, # No. of model and keep it odd number
    oob_score=True,
    max_depth=4
)

# now fit Randome Forest on Training Data
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)


print("OOB Score: ", rf.oob_score_ * 100, "&") 
print("Testing Accuracy: ", accuracy_score(y_test, y_pred) * 100, "&")
# Out:
# OOB Score:  81.70144462279293 &
# Testing Accuracy:  81.34328358208955 &

# %% [markdown]
# # Bagging Classifier and Regressor

# %%
# Begging CLassifier for Descision Classifier
from sklearn.ensemble import BaggingClassifier

base_model =  DecisionTreeClassifier()

bagging = BaggingClassifier(
    base_model,
    n_estimators=201
)

bagging.fit(X_train, y_train)

y_pred  = bagging.predict(X_test)

print("Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7723880597014925
